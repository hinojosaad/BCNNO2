# %%
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

# %%
aire01=pd.read_csv("2021_01_Gener_qualitat_aire_BCN.csv")
aire02=pd.read_csv("2021_02_Febrer_qualitat_aire_BCN.csv")
aire03=pd.read_csv("2021_03_Marc_qualitat_aire_BCN.csv")
aire04=pd.read_csv("2021_04_Abril_qualitat_aire_BCN.csv")
aire05=pd.read_csv("2021_05_Maig_qualitat_aire_BCN.csv")
aire06=pd.read_csv("2021_06_Juny_qualitat_aire_BCN.csv")
aire07=pd.read_csv("2021_07_Juliol_qualitat_aire_BCN.csv")
aire08=pd.read_csv("2021_08_Agost_qualitat_aire_BCN.csv")
aire09=pd.read_csv("2021_09_Setembre_qualitat_aire_BCN.csv")
aire10=pd.read_csv("2021_10_Octubre_qualitat_aire_BCN.csv")
aire11=pd.read_csv("2021_11_Novembre_qualitat_aire_BCN.csv")
aire12=pd.read_csv("2021_12_Desembre_qualitat_aire_BCN.csv")

# %%
aire12.head()
# Out:
#    CODI_PROVINCIA  PROVINCIA  CODI_MUNICIPI   MUNICIPI  ESTACIO  \
# 0               8  Barcelona             19  Barcelona        4
# 1               8  Barcelona             19  Barcelona        4
# 2               8  Barcelona             19  Barcelona        4
# 3               8  Barcelona             19  Barcelona        4
# 4               8  Barcelona             19  Barcelona        4
#
#    CODI_CONTAMINANT   ANY  MES  DIA   H01  ...    H20  V20    H21  V21    H22  \
# 0                 7  2021   12    1  23.0  ...    2.0    V    3.0    V    2.0
# 1                 7  2021   12    2   2.0  ...    8.0    V    2.0    V    2.0
# 2                 7  2021   12    3   3.0  ...  110.0    V  155.0    V  107.0
# 3                 7  2021   12    4  64.0  ...    1.0    V    1.0    V    1.0
# 4                 7  2021   12    5   1.0  ...    1.0    V    1.0    V    1.0
#
#    V22   H23  V23   H24  V24
# 0    V   2.0    V   1.0    V
# 1    V   1.0    V   2.0    V
# ...

# %%
aire12["ESTACIO"].value_counts()
# Out:
# 43    372
# 54    372
# 57    248
# 44    217
# 58    155
# 4     124
# 50    124
# 42     93
# Name: ESTACIO, dtype: int64

# %%
NO2_01_E43 = aire01[(aire01["CODI_CONTAMINANT"]== 8)&(aire01["ESTACIO"]==43)]
NO2_02_E43 = aire02[(aire02["CODI_CONTAMINANT"]== 8)&(aire02["ESTACIO"]==43)]
NO2_03_E43 = aire03[(aire03["CODI_CONTAMINANT"]== 8)&(aire03["ESTACIO"]==43)]
NO2_04_E43 = aire04[(aire04["CODI_CONTAMINANT"]== 8)&(aire04["ESTACIO"]==43)]
NO2_05_E43 = aire05[(aire05["CODI_CONTAMINANT"]== 8)&(aire05["ESTACIO"]==43)]
NO2_06_E43 = aire06[(aire06["CODI_CONTAMINANT"]== 8)&(aire06["ESTACIO"]==43)]
NO2_07_E43 = aire07[(aire07["CODI_CONTAMINANT"]== 8)&(aire07["ESTACIO"]==43)]
NO2_08_E43 = aire08[(aire08["CODI_CONTAMINANT"]== 8)&(aire08["ESTACIO"]==43)]
NO2_09_E43 = aire09[(aire09["CODI_CONTAMINANT"]== 8)&(aire09["ESTACIO"]==43)]
NO2_10_E43 = aire10[(aire10["CODI_CONTAMINANT"]== 8)&(aire10["ESTACIO"]==43)]
NO2_11_E43 = aire11[(aire11["CODI_CONTAMINANT"]== 8)&(aire11["ESTACIO"]==43)]
NO2_12_E43 = aire12[(aire12["CODI_CONTAMINANT"]== 8)&(aire12["ESTACIO"]==43)]
NO2_12_E43.head()
# Out:
#      CODI_PROVINCIA  PROVINCIA  CODI_MUNICIPI   MUNICIPI  ESTACIO  \
# 310               8  Barcelona             19  Barcelona       43
# 311               8  Barcelona             19  Barcelona       43
# 312               8  Barcelona             19  Barcelona       43
# 313               8  Barcelona             19  Barcelona       43
# 314               8  Barcelona             19  Barcelona       43
#
#      CODI_CONTAMINANT   ANY  MES  DIA   H01  ...   H20  V20   H21  V21   H22  \
# 310                 8  2021   12    1  49.0  ...  39.0    V  37.0    V  41.0
# 311                 8  2021   12    2  29.0  ...  63.0    V  71.0    V  50.0
# 312                 8  2021   12    3  26.0  ...  97.0    V  94.0    V  97.0
# 313                 8  2021   12    4  88.0  ...  37.0    V  22.0    V  34.0
# 314                 8  2021   12    5  18.0  ...  38.0    V  30.0    V  25.0
#
#      V22    H23  V23   H24  V24
# 310    V   26.0    V  30.0    V
# 311    V   43.0    V  34.0    V
# ...

# %%
NO2_01_E43=pd.melt(NO2_01_E43, id_vars=["ANY","MES","DIA"], value_vars=["H01","H02","H03","H04","H05","H06","H07","H08","H09","H10","H11","H12","H13","H14","H15","H16","H17","H18","H19","H20","H21","H22","H23","H24" ],var_name="hour", value_name="mg/m^3_43")
NO2_02_E43=pd.melt(NO2_02_E43, id_vars=["ANY","MES","DIA"], value_vars=["H01","H02","H03","H04","H05","H06","H07","H08","H09","H10","H11","H12","H13","H14","H15","H16","H17","H18","H19","H20","H21","H22","H23","H24" ],var_name="hour", value_name="mg/m^3_43")
NO2_03_E43=pd.melt(NO2_03_E43, id_vars=["ANY","MES","DIA"], value_vars=["H01","H02","H03","H04","H05","H06","H07","H08","H09","H10","H11","H12","H13","H14","H15","H16","H17","H18","H19","H20","H21","H22","H23","H24" ],var_name="hour", value_name="mg/m^3_43")
NO2_04_E43=pd.melt(NO2_04_E43, id_vars=["ANY","MES","DIA"], value_vars=["H01","H02","H03","H04","H05","H06","H07","H08","H09","H10","H11","H12","H13","H14","H15","H16","H17","H18","H19","H20","H21","H22","H23","H24" ],var_name="hour", value_name="mg/m^3_43")
NO2_05_E43=pd.melt(NO2_05_E43, id_vars=["ANY","MES","DIA"], value_vars=["H01","H02","H03","H04","H05","H06","H07","H08","H09","H10","H11","H12","H13","H14","H15","H16","H17","H18","H19","H20","H21","H22","H23","H24" ],var_name="hour", value_name="mg/m^3_43")
NO2_06_E43=pd.melt(NO2_06_E43, id_vars=["ANY","MES","DIA"], value_vars=["H01","H02","H03","H04","H05","H06","H07","H08","H09","H10","H11","H12","H13","H14","H15","H16","H17","H18","H19","H20","H21","H22","H23","H24" ],var_name="hour", value_name="mg/m^3_43")
NO2_07_E43=pd.melt(NO2_07_E43, id_vars=["ANY","MES","DIA"], value_vars=["H01","H02","H03","H04","H05","H06","H07","H08","H09","H10","H11","H12","H13","H14","H15","H16","H17","H18","H19","H20","H21","H22","H23","H24" ],var_name="hour", value_name="mg/m^3_43")
NO2_08_E43=pd.melt(NO2_08_E43, id_vars=["ANY","MES","DIA"], value_vars=["H01","H02","H03","H04","H05","H06","H07","H08","H09","H10","H11","H12","H13","H14","H15","H16","H17","H18","H19","H20","H21","H22","H23","H24" ],var_name="hour", value_name="mg/m^3_43")
NO2_09_E43=pd.melt(NO2_09_E43, id_vars=["ANY","MES","DIA"], value_vars=["H01","H02","H03","H04","H05","H06","H07","H08","H09","H10","H11","H12","H13","H14","H15","H16","H17","H18","H19","H20","H21","H22","H23","H24" ],var_name="hour", value_name="mg/m^3_43")
NO2_10_E43=pd.melt(NO2_10_E43, id_vars=["ANY","MES","DIA"], value_vars=["H01","H02","H03","H04","H05","H06","H07","H08","H09","H10","H11","H12","H13","H14","H15","H16","H17","H18","H19","H20","H21","H22","H23","H24" ],var_name="hour", value_name="mg/m^3_43")
NO2_11_E43=pd.melt(NO2_11_E43, id_vars=["ANY","MES","DIA"], value_vars=["H01","H02","H03","H04","H05","H06","H07","H08","H09","H10","H11","H12","H13","H14","H15","H16","H17","H18","H19","H20","H21","H22","H23","H24" ],var_name="hour", value_name="mg/m^3_43")
NO2_12_E43=pd.melt(NO2_12_E43, id_vars=["ANY","MES","DIA"], value_vars=["H01","H02","H03","H04","H05","H06","H07","H08","H09","H10","H11","H12","H13","H14","H15","H16","H17","H18","H19","H20","H21","H22","H23","H24" ],var_name="hour", value_name="mg/m^3_43")
NO2_12_E43
# Out:
#       ANY  MES  DIA hour  mg/m^3_43
# 0    2021   12    1  H01       49.0
# 1    2021   12    2  H01       29.0
# 2    2021   12    3  H01       26.0
# 3    2021   12    4  H01       88.0
# 4    2021   12    5  H01       18.0
# ..    ...  ...  ...  ...        ...
# 739  2021   12   27  H24       18.0
# 740  2021   12   28  H24       17.0
# 741  2021   12   29  H24       77.0
# 742  2021   12   30  H24       75.0
# 743  2021   12   31  H24       53.0
#
# [744 rows x 5 columns]

# %%
NO2_E43=pd.concat([NO2_01_E43, NO2_02_E43,NO2_03_E43, NO2_04_E43, NO2_05_E43, NO2_06_E43, NO2_07_E43,NO2_08_E43, NO2_09_E43, NO2_10_E43,NO2_11_E43,NO2_12_E43])
NO2_E43
# Out:
#       ANY  MES  DIA hour  mg/m^3_43
# 0    2021    1    1  H01       36.0
# 1    2021    1    2  H01       10.0
# 2    2021    1    3  H01       26.0
# 3    2021    1    4  H01       59.0
# 4    2021    1    5  H01       30.0
# ..    ...  ...  ...  ...        ...
# 739  2021   12   27  H24       18.0
# 740  2021   12   28  H24       17.0
# 741  2021   12   29  H24       77.0
# 742  2021   12   30  H24       75.0
# 743  2021   12   31  H24       53.0
#
# [8736 rows x 5 columns]

# %%
NO2_E43["hour"]=NO2_E43["hour"].apply(lambda x: int(x[1:]))
NO2_E43
# Out:
#       ANY  MES  DIA  hour  mg/m^3_43
# 0    2021    1    1     1       36.0
# 1    2021    1    2     1       10.0
# 2    2021    1    3     1       26.0
# 3    2021    1    4     1       59.0
# 4    2021    1    5     1       30.0
# ..    ...  ...  ...   ...        ...
# 739  2021   12   27    24       18.0
# 740  2021   12   28    24       17.0
# 741  2021   12   29    24       77.0
# 742  2021   12   30    24       75.0
# 743  2021   12   31    24       53.0
#
# [8736 rows x 5 columns]

# %%
from datetime import datetime
NO2_E43.rename(columns = {'ANY':'year', 'MES':'month',"DIA":"day",}, inplace = True)


NO2_E43["DATETIME"]=pd.to_datetime(NO2_E43[["year",'month', 'day', 'hour']])
NO2_E43= NO2_E43[["DATETIME","mg/m^3_43"]]
NO2_E43.set_index('DATETIME', inplace=True)
NO2_E43.sort_values(by="DATETIME",inplace=True)

NO2_E43
# Out:
#                      mg/m^3_43
# DATETIME
# 2021-01-01 01:00:00       36.0
# 2021-01-01 02:00:00       35.0
# 2021-01-01 03:00:00       33.0
# 2021-01-01 04:00:00       13.0
# 2021-01-01 05:00:00       12.0
# ...                        ...
# 2021-12-31 20:00:00       58.0
# 2021-12-31 21:00:00       63.0
# 2021-12-31 22:00:00       50.0
# 2021-12-31 23:00:00       50.0
# 2022-01-01 00:00:00       53.0
#
# [8736 rows x 1 columns]

# %%
NO2_E43[ "NAN"]= 1


for j in range(1,len(NO2_E43)):

    if NO2_E43["mg/m^3_43"].isna()[j] == False :
        NO2_E43[ "NAN"][j] =   NO2_E43[ "NAN"][j-1]+1   
        
        
    else:
        NO2_E43[ "NAN"][j] = 0
        
        
NO2_E43
# Out:
#                      mg/m^3_43  NAN
# DATETIME
# 2021-01-01 01:00:00       36.0    1
# 2021-01-01 02:00:00       35.0    2
# 2021-01-01 03:00:00       33.0    3
# 2021-01-01 04:00:00       13.0    4
# 2021-01-01 05:00:00       12.0    5
# ...                        ...  ...
# 2021-12-31 20:00:00       58.0  221
# 2021-12-31 21:00:00       63.0  222
# 2021-12-31 22:00:00       50.0  223
# 2021-12-31 23:00:00       50.0  224
# 2022-01-01 00:00:00       53.0  225
#
# [8736 rows x 2 columns]

# %%
#import matplotlib.pyplot as plt

#plt.plot(NO2_E43["mg/m^3_43"])
#plt.show()

# %%
#NO2_E43.to_csv("NO2_E43.csv")

# %%
NO2_E43L = NO2_E43[4648:5149]["mg/m^3_43"]

# %%
import seaborn as sbn

sbn.lineplot(data=NO2_E43L[:168])
plt.show()

# %%
import statsmodels.api as sm
from matplotlib import rcParams
from statsmodels.graphics import tsaplots

rcParams["figure.figsize"] = 10, 6

# Stands for Time Series Analysis Plots (TSA Plots)
fig = tsaplots.plot_acf(NO2_E43L, lags=50)

plt.xlabel("Lag at k")
plt.ylabel("Correlation coefficient")
plt.show()

# %%
NO2_E43L
