# %%
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

# %%
aire01=pd.read_csv("2021_01_Gener_qualitat_aire_BCN.csv")
aire02=pd.read_csv("2021_02_Febrer_qualitat_aire_BCN.csv")
aire03=pd.read_csv("2021_03_Marc_qualitat_aire_BCN.csv")
aire04=pd.read_csv("2021_04_Abril_qualitat_aire_BCN.csv")
aire05=pd.read_csv("2021_05_Maig_qualitat_aire_BCN.csv")
aire06=pd.read_csv("2021_06_Juny_qualitat_aire_BCN.csv")
aire07=pd.read_csv("2021_07_Juliol_qualitat_aire_BCN.csv")
aire08=pd.read_csv("2021_08_Agost_qualitat_aire_BCN.csv")
aire09=pd.read_csv("2021_09_Setembre_qualitat_aire_BCN.csv")
aire10=pd.read_csv("2021_10_Octubre_qualitat_aire_BCN.csv")
aire11=pd.read_csv("2021_11_Novembre_qualitat_aire_BCN.csv")
aire12=pd.read_csv("2021_12_Desembre_qualitat_aire_BCN.csv")

# %%
aire12.head()
# Out:
#    CODI_PROVINCIA  PROVINCIA  CODI_MUNICIPI   MUNICIPI  ESTACIO  \
# 0               8  Barcelona             19  Barcelona        4
# 1               8  Barcelona             19  Barcelona        4
# 2               8  Barcelona             19  Barcelona        4
# 3               8  Barcelona             19  Barcelona        4
# 4               8  Barcelona             19  Barcelona        4
#
#    CODI_CONTAMINANT   ANY  MES  DIA   H01  ...    H20  V20    H21  V21    H22  \
# 0                 7  2021   12    1  23.0  ...    2.0    V    3.0    V    2.0
# 1                 7  2021   12    2   2.0  ...    8.0    V    2.0    V    2.0
# 2                 7  2021   12    3   3.0  ...  110.0    V  155.0    V  107.0
# 3                 7  2021   12    4  64.0  ...    1.0    V    1.0    V    1.0
# 4                 7  2021   12    5   1.0  ...    1.0    V    1.0    V    1.0
#
#    V22   H23  V23   H24  V24
# 0    V   2.0    V   1.0    V
# 1    V   1.0    V   2.0    V
# ...

# %%
aire12["ESTACIO"].value_counts()
# Out:
# 43    372
# 54    372
# 57    248
# 44    217
# 58    155
# 4     124
# 50    124
# 42     93
# Name: ESTACIO, dtype: int64

# %%
NO2_01_E4 = aire01[(aire01["CODI_CONTAMINANT"]== 8)&(aire01["ESTACIO"]==4)]
NO2_02_E4 = aire02[(aire02["CODI_CONTAMINANT"]== 8)&(aire02["ESTACIO"]==4)]
NO2_03_E4 = aire03[(aire03["CODI_CONTAMINANT"]== 8)&(aire03["ESTACIO"]==4)]
NO2_04_E4 = aire04[(aire04["CODI_CONTAMINANT"]== 8)&(aire04["ESTACIO"]==4)]
NO2_05_E4 = aire05[(aire05["CODI_CONTAMINANT"]== 8)&(aire05["ESTACIO"]==4)]
NO2_06_E4 = aire06[(aire06["CODI_CONTAMINANT"]== 8)&(aire06["ESTACIO"]==4)]
NO2_07_E4 = aire07[(aire07["CODI_CONTAMINANT"]== 8)&(aire07["ESTACIO"]==4)]
NO2_08_E4 = aire08[(aire08["CODI_CONTAMINANT"]== 8)&(aire08["ESTACIO"]==4)]
NO2_09_E4 = aire09[(aire09["CODI_CONTAMINANT"]== 8)&(aire09["ESTACIO"]==4)]
NO2_10_E4 = aire10[(aire10["CODI_CONTAMINANT"]== 8)&(aire10["ESTACIO"]==4)]
NO2_11_E4 = aire11[(aire11["CODI_CONTAMINANT"]== 8)&(aire11["ESTACIO"]==4)]
NO2_12_E4 = aire12[(aire12["CODI_CONTAMINANT"]== 8)&(aire12["ESTACIO"]==4)]
NO2_12_E4.head()
# Out:
#     CODI_PROVINCIA  PROVINCIA  CODI_MUNICIPI   MUNICIPI  ESTACIO  \
# 31               8  Barcelona             19  Barcelona        4
# 32               8  Barcelona             19  Barcelona        4
# 33               8  Barcelona             19  Barcelona        4
# 34               8  Barcelona             19  Barcelona        4
# 35               8  Barcelona             19  Barcelona        4
#
#     CODI_CONTAMINANT   ANY  MES  DIA   H01  ...   H20  V20   H21  V21   H22  \
# 31                 8  2021   12    1  52.0  ...  24.0    V  29.0    V  20.0
# 32                 8  2021   12    2  23.0  ...  53.0    V  29.0    V  24.0
# 33                 8  2021   12    3  27.0  ...  81.0    V  85.0    V  74.0
# 34                 8  2021   12    4  57.0  ...  16.0    V  19.0    V  14.0
# 35                 8  2021   12    5  19.0  ...  22.0    V  18.0    V  19.0
#
#     V22   H23  V23   H24  V24
# 31    V  22.0    V  19.0    V
# 32    V  21.0    V  28.0    V
# ...

# %%
NO2_01_E4=pd.melt(NO2_01_E4, id_vars=["ANY","MES","DIA"], value_vars=["H01","H02","H03","H04","H05","H06","H07","H08","H09","H10","H11","H12","H13","H14","H15","H16","H17","H18","H19","H20","H21","H22","H23","H24" ],var_name="hour", value_name="mg/m^3_04")
NO2_02_E4=pd.melt(NO2_02_E4, id_vars=["ANY","MES","DIA"], value_vars=["H01","H02","H03","H04","H05","H06","H07","H08","H09","H10","H11","H12","H13","H14","H15","H16","H17","H18","H19","H20","H21","H22","H23","H24" ],var_name="hour", value_name="mg/m^3_04")
NO2_03_E4=pd.melt(NO2_03_E4, id_vars=["ANY","MES","DIA"], value_vars=["H01","H02","H03","H04","H05","H06","H07","H08","H09","H10","H11","H12","H13","H14","H15","H16","H17","H18","H19","H20","H21","H22","H23","H24" ],var_name="hour", value_name="mg/m^3_04")
NO2_04_E4=pd.melt(NO2_04_E4, id_vars=["ANY","MES","DIA"], value_vars=["H01","H02","H03","H04","H05","H06","H07","H08","H09","H10","H11","H12","H13","H14","H15","H16","H17","H18","H19","H20","H21","H22","H23","H24" ],var_name="hour", value_name="mg/m^3_04")
NO2_05_E4=pd.melt(NO2_05_E4, id_vars=["ANY","MES","DIA"], value_vars=["H01","H02","H03","H04","H05","H06","H07","H08","H09","H10","H11","H12","H13","H14","H15","H16","H17","H18","H19","H20","H21","H22","H23","H24" ],var_name="hour", value_name="mg/m^3_04")
NO2_06_E4=pd.melt(NO2_06_E4, id_vars=["ANY","MES","DIA"], value_vars=["H01","H02","H03","H04","H05","H06","H07","H08","H09","H10","H11","H12","H13","H14","H15","H16","H17","H18","H19","H20","H21","H22","H23","H24" ],var_name="hour", value_name="mg/m^3_04")
NO2_07_E4=pd.melt(NO2_07_E4, id_vars=["ANY","MES","DIA"], value_vars=["H01","H02","H03","H04","H05","H06","H07","H08","H09","H10","H11","H12","H13","H14","H15","H16","H17","H18","H19","H20","H21","H22","H23","H24" ],var_name="hour", value_name="mg/m^3_04")
NO2_08_E4=pd.melt(NO2_08_E4, id_vars=["ANY","MES","DIA"], value_vars=["H01","H02","H03","H04","H05","H06","H07","H08","H09","H10","H11","H12","H13","H14","H15","H16","H17","H18","H19","H20","H21","H22","H23","H24" ],var_name="hour", value_name="mg/m^3_04")
NO2_09_E4=pd.melt(NO2_09_E4, id_vars=["ANY","MES","DIA"], value_vars=["H01","H02","H03","H04","H05","H06","H07","H08","H09","H10","H11","H12","H13","H14","H15","H16","H17","H18","H19","H20","H21","H22","H23","H24" ],var_name="hour", value_name="mg/m^3_04")
NO2_10_E4=pd.melt(NO2_10_E4, id_vars=["ANY","MES","DIA"], value_vars=["H01","H02","H03","H04","H05","H06","H07","H08","H09","H10","H11","H12","H13","H14","H15","H16","H17","H18","H19","H20","H21","H22","H23","H24" ],var_name="hour", value_name="mg/m^3_04")
NO2_11_E4=pd.melt(NO2_11_E4, id_vars=["ANY","MES","DIA"], value_vars=["H01","H02","H03","H04","H05","H06","H07","H08","H09","H10","H11","H12","H13","H14","H15","H16","H17","H18","H19","H20","H21","H22","H23","H24" ],var_name="hour", value_name="mg/m^3_04")
NO2_12_E4=pd.melt(NO2_12_E4, id_vars=["ANY","MES","DIA"], value_vars=["H01","H02","H03","H04","H05","H06","H07","H08","H09","H10","H11","H12","H13","H14","H15","H16","H17","H18","H19","H20","H21","H22","H23","H24" ],var_name="hour", value_name="mg/m^3_04")
NO2_12_E4
# Out:
#       ANY  MES  DIA hour  mg/m^3_04
# 0    2021   12    1  H01       52.0
# 1    2021   12    2  H01       23.0
# 2    2021   12    3  H01       27.0
# 3    2021   12    4  H01       57.0
# 4    2021   12    5  H01       19.0
# ..    ...  ...  ...  ...        ...
# 739  2021   12   27  H24       23.0
# 740  2021   12   28  H24       15.0
# 741  2021   12   29  H24       44.0
# 742  2021   12   30  H24       39.0
# 743  2021   12   31  H24       37.0
#
# [744 rows x 5 columns]

# %%
NO2_12_E4["hour"]=NO2_12_E4["hour"].apply(lambda x: int(x[1:]))
NO2_12_E4
# Out:
#       ANY  MES  DIA  hour  mg/m^3_04
# 0    2021   12    1     1       52.0
# 1    2021   12    2     1       23.0
# 2    2021   12    3     1       27.0
# 3    2021   12    4     1       57.0
# 4    2021   12    5     1       19.0
# ..    ...  ...  ...   ...        ...
# 739  2021   12   27    24       23.0
# 740  2021   12   28    24       15.0
# 741  2021   12   29    24       44.0
# 742  2021   12   30    24       39.0
# 743  2021   12   31    24       37.0
#
# [744 rows x 5 columns]

# %%
from datetime import datetime
NO2_12_E4.rename(columns = {'ANY':'year', 'MES':'month',"DIA":"day",}, inplace = True)


NO2_12_E4["DATETIME"]=pd.to_datetime(NO2_12_E4[["year",'month', 'day', 'hour']])
NO2_12_E4= NO2_12_E4[["DATETIME","mg/m^3_04"]]
NO2_12_E4.set_index('DATETIME', inplace=True)
NO2_12_E4.sort_values(by="DATETIME",inplace=True)

NO2_12_E4
# Out:
#                      mg/m^3_04
# DATETIME
# 2021-12-01 01:00:00       52.0
# 2021-12-01 02:00:00       48.0
# 2021-12-01 03:00:00       39.0
# 2021-12-01 04:00:00       21.0
# 2021-12-01 05:00:00       12.0
# ...                        ...
# 2021-12-31 20:00:00       45.0
# 2021-12-31 21:00:00       42.0
# 2021-12-31 22:00:00       42.0
# 2021-12-31 23:00:00       43.0
# 2022-01-01 00:00:00       37.0
#
# [744 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(NO2_12_E4["mg/m^3_04"][:168])
plt.show()
